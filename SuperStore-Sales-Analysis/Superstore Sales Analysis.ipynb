# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv("Downloads/Superstore.csv/Superstore.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Year"] = df["Order Date"].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Year"].value_counts()
# Out:
# 2014    3319
# 2013    2580
# 2012    2102
# 2011    1993
# Name: Order Year, dtype: int64

# %%
sales_by_year = df.groupby(["Order Year"])["Sales"].sum().reset_index()
sales_by_year
# Out:
#    Order Year        Sales
# 0        2011  484247.4981
# 1        2012  470532.5090
# 2        2013  608473.8300
# 3        2014  733947.0232

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x ="Order Year", y = "Sales"  , data=sales_by_year, marker = "o", sort = False)
# Out:
# <AxesSubplot:xlabel='Order Year', ylabel='Sales'>

# %%
df = df.drop("Month_Year", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27864/2808038796.py in <module>
# ----> 1 df = df.drop("Month_Year", axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Month Year"] = df["Order Date"].dt.to_period("M").astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
sales_by_month = df.groupby(["Month Year"])["Sales"].sum().reset_index()
sales_by_month
# Out:
#    Month Year       Sales
# 0     2011-01  28484.8060
# 1     2011-02  13129.9300
# 2     2011-03  54899.9920
# 3     2011-04  24401.1320
# 4     2011-05  30042.7420
# 5     2011-06  24568.9546
# 6     2011-07  39811.3800
# 7     2011-08  38107.4655
# 8     2011-09  66084.2398
# 9     2011-10  34547.6610
# 10    2011-11  62819.1085
# 11    2011-12  67350.0867
# 12    2012-01  29087.9304
# 13    2012-02  20987.8080
# 14    2012-03  40876.6112
# 15    2012-04  38056.9685
# 16    2012-05  30933.7145
# 17    2012-06  28862.1982
# 18    2012-07  28730.3760
# 19    2012-08  50094.5280
# 20    2012-09  66729.3290
# 21    2012-10  32025.0750
# 22    2012-11  50732.3090
# 23    2012-12  53415.6612
# 24    2013-01  21998.1470
# 25    2013-02  41411.8460
# 26    2013-03  61470.8110
# 27    2013-04  48654.4390
# 28    2013-05  66946.5680
# 29    2013-06  44643.4538
# 30    2013-07  40454.6170
# 31    2013-08  45065.8533
# 32    2013-09  55505.9529
# 33    2013-10  34980.5330
# ...

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Month Year", y="Sales", data = sales_by_month)
plt.xticks(rotation=45)
plt.show()

# %%
df["Order Month"] = df["Order Date"].dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
agg_month = df.groupby(["Order Year","Order Month"])["Sales"].sum()

# %%
agg_month = agg_month.reset_index()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Order Month", y="Sales", hue = "Order Year", palette="RdBu" ,data = agg_month)
# Out:
# <AxesSubplot:xlabel='Order Month', ylabel='Sales'>

# %%
yearly_profits = df.groupby(["Order Year"])["Profit"].sum().reset_index()
yearly_profits
# Out:
#    Order Year      Profit
# 0        2011  49543.9741
# 1        2012  61618.6037
# 2        2013  81726.9308
# 3        2014  93507.5131

# %%
sns.lineplot(x="Order Year", y="Profit", data=yearly_profits, marker="o")
# Out:
# <AxesSubplot:xlabel='Order Year', ylabel='Profit'>

# %%
sales_group = df.groupby(["Order Year", "Category"])["Sales"].sum().reset_index()
sales_group
# Out:
#     Order Year         Category        Sales
# 0         2011        Furniture  157192.8531
# 1         2011  Office Supplies  151776.4120
# 2         2011       Technology  175278.2330
# 3         2012        Furniture  170518.2370
# 4         2012  Office Supplies  137233.4630
# 5         2012       Technology  162780.8090
# 6         2013        Furniture  198901.4360
# 7         2013  Office Supplies  183510.5900
# 8         2013       Technology  226061.8040
# 9         2014        Furniture  215387.2692
# 10        2014  Office Supplies  246526.5670
# 11        2014       Technology  272033.1870

# %%
profit_group = df.groupby(["Order Year", "Category"])["Profit"].sum().reset_index()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Order Year", y="Sales", hue="Category",palette= "coolwarm", data=sales_group)
# Out:
# <AxesSubplot:xlabel='Order Year', ylabel='Sales'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Order Year", y="Profit", hue="Category",palette= "coolwarm", data=profit_group)
# Out:
# <AxesSubplot:xlabel='Order Year', ylabel='Profit'>

# %%
group = pd.pivot_table(df, values=["Sales", "Profit"], index="Category", aggfunc= "sum")
group
# Out:
#                       Profit        Sales
# Category
# Furniture         18451.2728  741999.7953
# Office Supplies  122490.8008  719047.0320
# Technology       145454.9481  836154.0330

# %%
group.plot(kind="bar", stacked=False, figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
sales_by_category = df.groupby(["Category"])["Sales"].sum().reset_index()
sales_by_category
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
plt.pie(x="Sales", data=sales_by_category, labels="Category", autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22429c94220>,
# ...
#  [Text(0.5806251240511282, 0.9342775098013503, 'Furniture'),
#   Text(-1.0908936275896106, 0.14124833904998657, 'Office Supplies'),
#   Text(0.4558499046992793, -1.0010998273826932, 'Technology')],
#  [Text(0.31670461311879716, 0.5096059144371001, '32%'),
#   Text(-0.5950328877761512, 0.07704454857271993, '31%'),
#   Text(0.24864540256324322, -0.5460544512996508, '36%')])

# %%
subcategory = df[df["Category"]=="Technology"].groupby(["Sub-Category"])["Sales"].sum().reset_index()
subcategory
# Out:
#   Sub-Category       Sales
# 0  Accessories  167380.318
# 1      Copiers  149528.030
# 2     Machines  189238.631
# 3       Phones  330007.054

# %%
subcategory.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.pie(x="Sales", data=subcategory, labels="Sub-Category", autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x224298363a0>,
# ...
#  [Text(0.8895553333369165, 0.6470636050125578, 'Accessories'),
#   Text(-0.27083330221719343, 1.0661375719906556, 'Copiers'),
#   Text(-1.098668145556986, 0.05411382391194936, 'Machines'),
#   Text(0.3573796691109339, -1.0403267621791528, 'Phones')],
#  [Text(0.4852120000019544, 0.35294378455230424, '20.0%'),
#   Text(-0.14772725575483275, 0.5815295847221758, '17.9%'),
#   Text(-0.5992735339401741, 0.02951663122469965, '22.6%'),
#   Text(0.1949343649696003, -0.5674509611886287, '39.5%')])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-12-11    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
phones = df[df["Sub-Category"]=="Phones"].groupby(["Product Name"])["Sales"].sum().sort_values(ascending=False).reset_index()
phones
# Out:
#                                           Product Name      Sales
# 0                              Samsung Galaxy Mega 6.3  13943.668
# 1                                       Apple iPhone 5  12996.600
# 2             Wilson Electronics DB Pro Signal Booster   8878.400
# 3                         Mitel MiVoice 5330e IP Phone   7699.720
# 4    Samsung Galaxy S III - 16GB - pebble blue (T-M...   7139.796
# ..                                                 ...        ...
# 184                        Shocksock Galaxy S4 Armband     63.510
# 185           Anker 24W Portable Micro USB Car Charger     61.544
# 186  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...     56.164
# 187  Sannysis Cute Owl Design Soft Skin Case Cover ...     13.860
# 188                  PNY Rapid USB Car Charger - Black      9.588
#
# [189 rows x 2 columns]

# %%
sns.scatterplot(x="Sales", y="Profit", data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
sns.regplot(x="Sales", y="Profit", data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Sales', y='Profit', data=df, color='red')

plt.title('Regression Plot of Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')

plt.show()

# %%
category_profit=df.groupby("Category")["Profit"].sum().reset_index()
category_profit
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
plt.pie(x="Profit",data=category_profit, autopct="%1.1f%%", labels= "Category")
# Out:
# ([<matplotlib.patches.Wedge at 0x2242af43d30>,
# ...
#  [Text(1.0775459327214676, 0.2211216020098955, 'Furniture'),
#   Text(-0.19438549183984183, 1.0826884503688874, 'Office Supplies'),
#   Text(-0.027224072906978994, -1.0996630619668717, 'Technology')],
#  [Text(0.5877523269389823, 0.12061178291448844, '6.4%'),
#   Text(-0.10602845009445917, 0.5905573365648477, '42.8%'),
#   Text(-0.014849494312897631, -0.5998162156182936, '50.8%')])

# %%
df.groupby('Product Name')['Order ID'].count().sort_values(ascending=False)
# Out:
# Product Name
# Staples                                                                      227
# Avery Non-Stick Binders                                                       20
# KI Adjustable-Height Table                                                    18
# Storex Dura Pro Binders                                                       17
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling                     15
#                                                                             ...
# Konica Minolta magicolor 1690MF Multifunction Printer                          1
# Xerox 1984                                                                     1
# Cisco Desktop Collaboration Experience DX650 IP Video Phone                    1
# Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection      1
# Cisco SPA525G2 5-Line IP Phone                                                 1
# Name: Order ID, Length: 1841, dtype: int64

# %%
df.groupby('Product Name')['Order ID'].count().sort_values(ascending=False)/df['Order ID'].nunique()*100
# Out:
# Product Name
# Staples                                                                      4.531843
# Avery Non-Stick Binders                                                      0.399281
# KI Adjustable-Height Table                                                   0.359353
# Storex Dura Pro Binders                                                      0.339389
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling                    0.299461
#                                                                                ...
# Konica Minolta magicolor 1690MF Multifunction Printer                        0.019964
# Xerox 1984                                                                   0.019964
# Cisco Desktop Collaboration Experience DX650 IP Video Phone                  0.019964
# Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection    0.019964
# Cisco SPA525G2 5-Line IP Phone                                               0.019964
# ...

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-09-11 2013-12-11    Second Class
# 1          2  CA-2013-152156 2013-09-11 2013-12-11    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-11-10 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-11-10 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-10-05    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
profit = df.groupby(["Product Name"])["Profit"].sum().sort_values(ascending=False).reset_index()
profit
# Out:
#                                            Product Name      Profit
# 0                 Canon imageCLASS 2200 Advanced Copier  25199.9280
# 1     Fellowes PB500 Electric Punch Plastic Comb Bin...   7753.0390
# 2                  Hewlett Packard LaserJet 3310 Copier   6983.8836
# 3                    Canon PC1060 Personal Laser Copier   4570.9347
# 4     HP Designjet T520 Inkjet Large Format Printer ...   4094.9766
# ...                                                 ...         ...
# 1836  Bush Advantage Collection Racetrack Conference...  -1934.3976
# 1837  Chromcraft Bull-Nose Wood Oval Conference Tabl...  -2876.1156
# 1838          Cubify CubeX 3D Printer Triple Head Print  -3839.9904
# 1839          Lexmark MX611dhe Monochrome Laser Printer  -4589.9730
# 1840          Cubify CubeX 3D Printer Double Head Print  -8879.9704
#
# [1841 rows x 2 columns]

# %%
profit = df.groupby(["Product Name"])["Profit"].sum().sort_values(ascending=False).reset_index()
profit[profit["Profit"]<0]
# Out:
#                                            Product Name        Profit
# 1540                           Global Super Steno Chair -1.776357e-15
# 1541                     Premier Electric Letter Opener -7.105427e-15
# 1542  Acco PRESSTEX Data Binder with Storage Hooks, ... -1.614000e-01
# 1543                                   Rubber Band Ball -2.992000e-01
# 1544                 Brites Rubber Bands, 1 1/2 oz. Box -5.148000e-01
# ...                                                 ...           ...
# 1836  Bush Advantage Collection Racetrack Conference... -1.934398e+03
# 1837  Chromcraft Bull-Nose Wood Oval Conference Tabl... -2.876116e+03
# 1838          Cubify CubeX 3D Printer Triple Head Print -3.839990e+03
# 1839          Lexmark MX611dhe Monochrome Laser Printer -4.589973e+03
# 1840          Cubify CubeX 3D Printer Double Head Print -8.879970e+03
#
# [301 rows x 2 columns]

# %%
sales_by_category
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
sales = df.groupby(["Product Name"])["Sales"].sum().sort_values(ascending=False).reset_index()
sales
# Out:
#                                            Product Name      Sales
# 0                 Canon imageCLASS 2200 Advanced Copier  61599.824
# 1     Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 2     Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 3          HON 5400 Series Task Chairs for Big and Tall  21870.576
# 4            GBC DocuBind TL300 Electric Binding System  19823.479
# ...                                                 ...        ...
# 1836  Avery Hi-Liter Pen Style Six-Color Fluorescent...      7.700
# 1837                                Grip Seal Envelopes      7.072
# 1838                                           Xerox 20      6.480
# 1839                                            Avery 5      5.760
# 1840  Eureka Disposable Bags for Sanitaire Vibra Gro...      1.624
#
# [1841 rows x 2 columns]

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-09-11 2013-12-11    Second Class
# 1          2  CA-2013-152156 2013-09-11 2013-12-11    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-11-10 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-11-10 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-04-03  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-10-05    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
sns.scatterplot(x="Sales", y="Profit", hue = "Category", data=df)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
order_id_sales= df.groupby("Order ID")["Sales"].sum().sort_values().reset_index()

# %%
order_id_sales
# Out:
#             Order ID      Sales
# 0     CA-2014-124114      0.556
# 1     CA-2013-168361      0.836
# 2     CA-2011-112403      0.852
# 3     US-2011-152723      0.876
# 4     US-2014-100209      1.080
# ...              ...        ...
# 5004  CA-2011-139892  10539.896
# 5005  CA-2014-127180  13716.458
# 5006  CA-2014-140151  14052.480
# 5007  CA-2013-118689  18336.740
# 5008  CA-2011-145317  23661.228
#
# [5009 rows x 2 columns]

# %%
order_id_profit= df.groupby("Order ID")["Profit"].sum().sort_values().reset_index()

# %%
order_id_profit
# Out:
#             Order ID     Profit
# 0     CA-2013-108196 -6892.3748
# 1     US-2014-168116 -3825.3394
# 2     CA-2011-169019 -3791.1634
# 3     CA-2014-134845 -3424.3546
# 4     US-2014-122714 -2929.4845
# ...              ...        ...
# 5004  CA-2011-116904  4668.6935
# 5005  CA-2013-117121  4946.3700
# 5006  CA-2014-166709  5039.9856
# 5007  CA-2014-140151  6734.4720
# 5008  CA-2013-118689  8762.3891
#
# [5009 rows x 2 columns]

# %%
df[df["Order ID"]=="CA-2013-108196"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7771    7772  CA-2013-108196 2013-11-26 2013-03-12  Standard Class
# 7772    7773  CA-2013-108196 2013-11-26 2013-03-12  Standard Class
# 7773    7774  CA-2013-108196 2013-11-26 2013-03-12  Standard Class
#
#      Customer ID  Customer Name   Segment        Country       City  ...  \
# 7771    CS-12505  Cindy Stewart  Consumer  United States  Lancaster  ...
# 7772    CS-12505  Cindy Stewart  Consumer  United States  Lancaster  ...
# 7773    CS-12505  Cindy Stewart  Consumer  United States  Lancaster  ...
#
#              Category  Sub-Category  \
# 7771  Office Supplies       Binders
# 7772       Technology      Machines
# 7773       Technology   Accessories
#
#                                           Product Name     Sales Quantity  \
# 7771  GBC Ibimaster 500 Manual ProClick Binding System   456.588        2
# 7772         Cubify CubeX 3D Printer Double Head Print  4499.985        5
# ...

# %%
df["Discount"].max()
# Out:
# 0.8

# %%
df[df["Discount"]==0.8]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 14        15  US-2012-118983 2012-11-22 2012-11-26  Standard Class
# 15        16  US-2012-118983 2012-11-22 2012-11-26  Standard Class
# 75        76  US-2014-118038 2014-10-12 2014-12-12     First Class
# 101      102  CA-2013-158568 2013-08-30 2013-03-09  Standard Class
# 169      170  CA-2011-139892 2011-08-09 2011-12-09  Standard Class
# ...      ...             ...        ...        ...             ...
# 9794    9795  CA-2011-127166 2011-05-21 2011-05-23    Second Class
# 9795    9796  CA-2013-125920 2013-05-22 2013-05-29  Standard Class
# 9808    9809  CA-2014-145093 2014-07-22 2014-07-27  Standard Class
# 9835    9836  CA-2013-126627 2013-11-10 2013-10-13     First Class
# 9920    9921  CA-2013-149272 2013-03-16 2013-03-20  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# 14      HP-14815     Harold Pawlan  Home Office  United States   Fort Worth
# ...
